# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
july2 = pd.read_csv('darcy_well_animation_test.csv')
july2.head()
# Out:
#       LAF       ST      AST   REV-ST  REV-AST     TMP  \
# 0   9.252  3450.99  3257.39  3695.13  3491.88  25.345
# 1   9.506  3443.45  3219.85  3686.03  3454.46  23.719
# 2   9.761  3434.73  3181.63  3677.61  3415.49  22.042
# 3  10.015  3425.12  3144.08  3669.29  3376.00  20.387
# 4  10.269  3418.67  3112.64  3660.58  3337.85  18.863
#
#                  start_time  depth_m datetime           label   leg  depth_ft
# 0  2026-07-02T17:01:45.975Z    0.252  01:46.0  7/2/2026 17:01  down  0.826772
# 1  2026-07-02T17:01:45.975Z    0.506  01:46.0  7/2/2026 17:01  down  1.660105
# 2  2026-07-02T17:01:45.975Z    0.761  01:46.0  7/2/2026 17:01  down  2.496719
# 3  2026-07-02T17:01:45.975Z    1.015  01:46.0  7/2/2026 17:01  down  3.330053
# 4  2026-07-02T17:01:45.975Z    1.269  01:46.0  7/2/2026 17:01  down  4.163386

# %%
fig, ax = plt.subplots()

ax.scatter(july2.TMP, july2.LAF, s=1)

ax.invert_yaxis()

# %%
july2.columns = july2.columns.str.strip()

# %%
july2["label"] = pd.to_datetime(july2["label"])
july2.head()
# Out:
#       LAF       ST      AST   REV-ST  REV-AST     TMP  \
# 0   9.252  3450.99  3257.39  3695.13  3491.88  25.345
# 1   9.506  3443.45  3219.85  3686.03  3454.46  23.719
# 2   9.761  3434.73  3181.63  3677.61  3415.49  22.042
# 3  10.015  3425.12  3144.08  3669.29  3376.00  20.387
# 4  10.269  3418.67  3112.64  3660.58  3337.85  18.863
#
#                  start_time  depth_m datetime               label   leg  \
# 0  2026-07-02T17:01:45.975Z    0.252  01:46.0 2026-07-02 17:01:00  down
# 1  2026-07-02T17:01:45.975Z    0.506  01:46.0 2026-07-02 17:01:00  down
# 2  2026-07-02T17:01:45.975Z    0.761  01:46.0 2026-07-02 17:01:00  down
# 3  2026-07-02T17:01:45.975Z    1.015  01:46.0 2026-07-02 17:01:00  down
# 4  2026-07-02T17:01:45.975Z    1.269  01:46.0 2026-07-02 17:01:00  down
#
#    depth_ft
# 0  0.826772
# 1  1.660105
# 2  2.496719
# 3  3.330053
# 4  4.163386

# %%
july2hour = july2.drop_duplicates(subset='label')

# %%
plt.figure()

for date, group in july2july2.groupby('label'):
    plt.plot(group['TMP'], group['depth_ft'], label=date.strftime('%y-%m-%d'))

plt.gca().invert_yaxis()
plt.gca().set_xlim(10, 13)

plt.show()

# %%
july2hour
# Out:
#         LAF       ST      AST   REV-ST  REV-AST     TMP  \
# 0     9.252  3450.99  3257.39  3695.13  3491.88  25.345
# 293   9.252  3400.78  3210.22  3781.97  3570.80  25.279
# 586   9.252  3585.86  3383.40  3714.17  3504.67  25.184
# 879   9.252  3433.75  3240.39  3755.75  3546.53  25.156
# 1172  9.252  3348.29  3160.98  3841.32  3627.71  25.123
# 1465  9.252  3400.92  3213.21  3732.12  3529.04  25.182
# 1758  9.252  3461.11  3270.48  3783.31  3578.34  25.221
# 2051  9.252  3449.98  3260.78  3752.50  3553.42  25.333
# 2344  9.252  3458.92  3271.00  3597.60  3409.01  25.460
# 2637  9.252  3379.31  3195.07  3756.95  3562.89  25.575
#
#                     start_time  depth_m datetime               label   leg  \
# 0     2026-07-02T17:01:45.975Z    0.252  01:46.0 2026-07-02 17:01:00  down
# 293   2026-07-02T17:13:48.961Z    0.252  13:49.0 2026-07-02 17:13:00  down
# 586   2026-07-02T17:25:52.275Z    0.252  25:52.3 2026-07-02 17:25:00  down
# ...

# %%
a = july2.iloc[0:292]
b = july2.iloc[293:585]
c = july2.iloc[586:878]
d = july2.iloc[879:1171]
e = july2.iloc[1172:1464]
f = july2.iloc[1465:1757]
g = july2.iloc[1758:2050]
h = july2.iloc[2051:2343]
i = july2.iloc[2344:2637]

# %%
fig, ax = plt.subplots()

ax.plot(a.TMP, a.depth_ft)
ax.plot(b.TMP, b.depth_ft)
ax.plot(c.TMP, c.depth_ft)
ax.plot(d.TMP, d.depth_ft)
ax.plot(e.TMP, e.depth_ft)
ax.plot(f.TMP, f.depth_ft)
ax.plot(g.TMP, g.depth_ft)
ax.plot(h.TMP, h.depth_ft)
ax.plot(i.TMP, i.depth_ft)

ax.invert_yaxis()
ax.set_xlim(10, 13)

plt.show()

# %%
import seaborn as sns

# %%
# doodoobananas seaborn plot what is even happening here 
sns.lineplot(x='TMP', y='depth_ft', data=july2, hue='label')
# Out:
# <Axes: xlabel='TMP', ylabel='depth_ft'>

# %%
july2
# Out:
#          LAF       ST      AST   REV-ST  REV-AST     TMP  \
# 0      9.252  3450.99  3257.39  3695.13  3491.88  25.345
# 1      9.506  3443.45  3219.85  3686.03  3454.46  23.719
# 2      9.761  3434.73  3181.63  3677.61  3415.49  22.042
# 3     10.015  3425.12  3144.08  3669.29  3376.00  20.387
# 4     10.269  3418.67  3112.64  3660.58  3337.85  18.863
# ...      ...      ...      ...      ...      ...     ...
# 2925  82.462  3218.89  2803.85  3776.57  3295.54  11.042
# 2926  82.716  3217.89  2803.22  3777.69  3297.43  11.072
# 2927  82.970  3191.08  2784.27  3776.40  3300.62  11.314
# 2928  83.224  3079.68  2699.14  3792.28  3321.93  11.879
# 2929  83.478  2927.88  2572.99  3869.39  3393.24  12.199
#
#                     start_time  depth_m datetime               label   leg  \
# 0     2026-07-02T17:01:45.975Z    0.252  01:46.0 2026-07-02 17:01:00  down
# 1     2026-07-02T17:01:45.975Z    0.506  01:46.0 2026-07-02 17:01:00  down
# ...

# %%
july2bottom = july2[july2['depth_ft'] >= 24]

# %%
# Source - https://stackoverflow.com/a/70353931
# Posted by user7864386, modified by community. See post 'Timeline' for change history
# Retrieved 2026-07-16, License - CC BY-SA 4.0

array = july2bottom.pivot(values=['TMP'], columns=['label'], index=['depth_ft']).to_numpy()

# %%
array
# Out:
# array([[10.381, 10.362, 10.377, ..., 10.369, 10.384, 10.394],
#        [10.536, 10.516, 10.534, ..., 10.564, 10.574, 10.56 ],
#        [10.71 , 10.689, 10.713, ..., 10.779, 10.796, 10.761],
#        ...,
#        [11.238, 11.278, 11.289, ..., 11.205, 11.214, 11.314],
#        [11.811, 11.851, 11.8  , ..., 11.769, 11.798, 11.879],
#        [12.116, 12.16 , 12.091, ..., 12.083, 12.114, 12.199]],
#       shape=(265, 10))

# %%
# making a heatmap 

# depth = july2.depth_ft
# time = july2.label
# temp = array

# fig, ax = plt.subplots(
#     # figsize=(20,2)
# )
# im = ax.imshow(temp)

# fig.tight_layout()
# plt.show()

sns.heatmap(array, annot=False, cmap='viridis')
# Out:
# <Axes: >

# %%
fig, ax = plt.subplots()
plt.gca().invert_yaxis()
plt.gca().set_xlim(10, 13)
artists = []

for date, group in july2.groupby('label'):
    line, = ax.plot(group['TMP'], group['depth_ft'], label=date.strftime('%y-%m-%d'))
    artists.append([line])
    
ani = animation.ArtistAnimation(fig=fig, artists=artists, interval=400)
plt.show()
ani.save('darcy.gif')
# Out:
# MovieWriter ffmpeg unavailable; using Pillow instead.

# %%
plt.figure()

for date, group in july2.groupby('label'):
    plt.plot(group['TMP'], group['depth_ft'], label=date.strftime('%y-%m-%d'))

plt.gca().invert_yaxis()
plt.gca().set_xlim(10, 13)

plt.show()

# %%
# trying a funcanimation
import functools
import matplotlib.animation as animation

# # Setting up a random number generator with a fixed state for reproducibility.
# rng = np.random.default_rng(seed=19680801)
# # Fixing bin edges.
# HIST_BINS = np.linspace(-4, 4, 100)

# # Histogram our data with numpy.
# data = rng.standard_normal(1000)
# n, _ = np.histogram(data, HIST_BINS)

# my data
data =
