# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
import os

print(os.getcwd())
print(os.listdir("."))
# Out:
# C:\Users\HydroResearch\Documents\GitHub\summer_26\summer 2026
# ['.ipynb_checkpoints', 'bell2026.ipynb', 'bell2026.yml', 'P1_All_6.16.csv', 'P1_Day_June15Only.csv', 'P1_ManualData.csv', 'P1_Month_MayOnly.csv', 'Spring Creek Bell Field Project', 'Well_Sampling_Data_P1.csv']

# %%
hobodf = pd.read_csv("P1_All_6.16.csv")
hobodf["Date-Time (CST/CDT)"] = pd.to_datetime(hobodf["Date-Time (CST/CDT)"])

date = hobodf["Date-Time (CST/CDT)"]
temp = hobodf["Temperature (W-CT 22414702), °C"]
mandate = pd.to_datetime(["11/11/2025 12:00:00", "11/18/2025 12:00:00", "1/06/2026 12:00:00", "1/13/2026 12:00:00", "2/3/2026 12:00:00", "2/17/2026 12:00:00", "2/24/2026 12:00:00", "3/3/2026 12:00:00", "3/10/2026 12:00:00", "3/31/2026 12:00:00", "4/7/2026 12:00:00", "4/14/2026 12:00:00", "4/21/2026 12:00:00", "4/28/2026 12:00:00", "5/12/2026 12:00:00", "5/19/2026 12:00:00", "5/26/2026 12:00:00", "6/16/2026  12:00:00"])
mantemp = [15, 14.2, 9.2, 8.9, 7.5, 6.7, 6.3, 6, 5.6, 5.4, 5.5, 5.6, 5.8, 7.3, 7, 7.2, 7.8, 9.8]

fig, ax = plt.subplots()
ax.plot(date, temp, color="blue")
ax.plot(mandate, mantemp, 'x', color = "red")
plt.xlabel("Year-Month")
plt.ylabel("Temperature (°C)")
plt.legend

plt.show()

# %%
mandf = pd.read_csv("Well_Sampling_Data_P1.csv", index_col=False)
mandf
# Out:
#    Well                Date  Depth to water  Temp top before  \
# 0    P1   9/16/2025 0:00:00            5.04             17.8
# 1    P1   9/30/2025 0:00:00            5.06             18.9
# 2    P1   10/7/2025 0:00:00            5.03             18.8
# 3    P1  10/14/2025 0:00:00            5.10             17.2
# 4    P1  10/28/2025 0:00:00            5.09             15.0
# 5    P1   11/4/2025 0:00:00            5.08             14.1
# 6    P1  11/11/2025 0:00:00            5.09             13.0
# 7    P1  11/18/2025 0:00:00            5.11             12.2
# 8    P1    1/6/2026 0:00:00             NaN              6.1
# 9    P1   1/13/2026 0:00:00            5.17              6.0
# 10   P1    2/3/2026 0:00:00            5.31              3.3
# 11   P1   2/17/2026 0:00:00            5.22              2.8
# 12   P1   2/24/2026 0:00:00            5.27              2.7
# 13   P1    3/3/2026 0:00:00            5.30              3.2
# 14   P1   3/10/2026 0:00:00            5.29              2.8
# 15   P1   3/31/2026 0:00:00            5.29              5.8
# 16   P1    4/7/2026 0:00:00            5.23              5.3
# 17   P1   4/14/2026 0:00:00             NaN              7.3
# 18   P1   4/21/2026 0:00:00            5.23              8.1
# 19   P1   4/28/2026 0:00:00            5.21              9.1
# 20   P1   5/12/2026 0:00:00            5.31              8.8
# 21   P1   5/19/2026 0:00:00            5.22             10.3
# 22   P1   5/26/2026 0:00:00            5.31             11.7
# 23   P1   6/16/2026 0:00:00            5.32             14.5
#
#     Temp bottom before  SPC top before  SPC bottom before  Cond top before   \
# 0                  NaN             765                NaN               659
# 1                  NaN             772              796.0               683
# 2                 18.0             797              795.0               703
# 3                 17.2             819              809.0               697
# 4                 15.7             853              844.0               691
# 5                 15.6             851              845.0               673
# 6                 15.0             867              848.0               667
# 7                 14.2             865              850.0               655
# 8                  9.2             824              823.0               526
# 9                  8.9             830              819.0               530
# 10                 7.5             829              822.0               485
# 11                 6.7             791              821.0               456
# 12                 6.3             827              819.0               476
# 13                 6.0             834              820.0               492
# 14                 5.6             834              824.0               483
# 15                 5.4             834              848.0               528
# 16                 5.5             825              850.0               506
# 17                 5.6             844              875.0               561
# 18                 5.8             856              877.0               582
# 19                 7.3             839              838.0               588
# 20                 7.0             843              872.0               582
# 21                 7.2             847              864.0               610
# 22                 7.8             835              871.0               627
# 23                 9.8             841              868.0               672
#
#     Cond bottom before   Salinity top before  ...  Recharge time  \
# 0                   NaN                  0.4  ...            NaN
# 1                 673.0                  0.4  ...            NaN
# 2                 689.0                  0.4  ...            NaN
# 3                 687.0                  0.4  ...            NaN
# 4                 695.0                  0.4  ...            NaN
# 5                 693.0                  0.4  ...        0:51.82
# 6                 686.0                  0.4  ...        0:47.29
# 7                 674.0                  0.4  ...        0:45.68
# 8                 576.0                  0.4  ...            NaN
# 9                 566.0                  0.4  ...       00:34.00
# 10                548.0                  0.4  ...        00:54.0
# 11                534.0                  0.4  ...       00:51.88
# 12                525.0                  0.4  ...        1:56.48
# 13                522.0                  0.4  ...       02:14.00
# 14                518.0                  0.4  ...       01:30.00
# 15                532.0                  0.4  ...       00:53.49
# 16                533.0                  0.4  ...        1:03.17
# 17                552.0                  0.4  ...       00:34.00
# 18                557.0                  0.4  ...       01:19.16
# 19                555.0                  0.4  ...       00:59.88
# 20                573.0                  0.4  ...       01:24.45
# 21                572.0                  0.4  ...       00:48.07
# 22                586.0                  0.4  ...       00:47.97
# 23                617.0                  0.4  ...            NaN
#
#    Temp top after Temp bottom after  SPC top after  SPC bottom after  \
# 0            18.2               NaN          630.0               NaN
# 1            19.0              17.3          677.0             648.0
# 2            18.9              17.2          699.0             668.0
# 3            16.9              17.1          662.0             662.0
# 4            15.0              15.7          653.0             647.0
# 5            14.5              15.7          631.0             671.0
# 6            13.0              14.0          821.0             799.0
# 7            12.8              14.5          803.0             828.0
# 8             NaN               NaN            NaN               NaN
# 9             7.2               8.9          812.0             810.0
# 10            4.5               7.4          805.0             813.0
# 11            4.4               6.5          806.0             816.0
# 12            4.3               6.1          802.0             814.0
# 13            4.0               5.9          801.0             816.0
# 14            3.9               5.5          801.0             804.0
# 15            6.0               5.3          810.0             812.0
# 16            5.6               5.4          788.0             805.0
# 17            6.9               5.5          828.0             828.0
# 18            7.5               6.7          836.0             826.0
# 19            7.8               6.2          812.0             831.0
# 20            8.6               7.1          821.0             837.0
# 21            9.2               7.3          817.0             840.0
# 22           10.8               7.9          816.0             837.0
# 23           13.1              10.1          802.0             833.0
#
#     Cond top after  Cond bottom after  Salinity top after  \
# 0            726.0                NaN                 0.4
# 1            765.0              760.0                 0.4
# 2            791.0              784.0                 0.4
# 3            783.0              780.0                 0.4
# 4            808.0              787.0                 0.4
# 5            790.0              817.0                 0.4
# 6            633.0              634.0                 0.4
# 7            615.0              661.0                 0.4
# 8              NaN                NaN                 NaN
# 9            538.0              561.0                 0.4
# 10           490.0              538.0                 0.4
# 11           491.0              528.0                 0.4
# 12           485.0              522.0                 0.3
# 13           481.0              518.0                 0.4
# 14           481.0              504.0                 0.4
# 15           504.0              507.0                 0.4
# 16           498.0              504.0                 0.4
# 17           535.0              520.0                 0.4
# 18           555.0              538.0                 0.4
# 19           546.0              534.0                 0.4
# 20           565.0              551.0                 0.4
# 21           570.0              556.0                 0.4
# 22           597.0              565.0                 0.4
# 23           621.0              594.0                 0.4
#
#     Salinity bottom after                                              Notes
# 0                     NaN  Recharge time too fast to measure. We pumped w...
# 1                     0.4                Recharge time too fast to measure.
# 2                     0.4                 Recharge time too fast to measure.
# 3                     0.4                                                NaN
# 4                     0.4                 Recharge time too fast to measure.
# 5                     0.4  for about 0.92ft of recharge   added a stick t...
# 6                     0.4                                                NaN
# 7                     0.4                                                NaN
# 8                     NaN                                                NaN
# 9                     0.4                                                NaN
# 10                    0.4                                                NaN
# 11                    0.4                                                NaN
# 12                    0.4                                                NaN
# 13                    0.4                                                NaN
# 14                    0.4                                                NaN
# 15                    0.4                                                NaN
# 16                    0.4                                                NaN
# 17                    0.4                                                NaN
# 18                    0.4                                                NaN
# 19                    0.4                                                NaN
# 20                    0.4                                                NaN
# 21                    0.4                                                NaN
# 22                    0.4                                                NaN
# 23                    0.4                                                NaN
#
# [24 rows x 22 columns]

# %%
for i, col in enumerate(mandf.columns):
    print(f"Index {i}: '{col}'")
# Out:
# Index 0: 'Well'
# Index 1: 'Date'
# Index 2: 'Depth to water'
# Index 3: 'Temp top before'
# Index 4: 'Temp bottom before'
# Index 5: 'SPC top before'
# Index 6: 'SPC bottom before'
# Index 7: 'Cond top before '
# Index 8: 'Cond bottom before '
# Index 9: 'Salinity top before'
# Index 10: 'Salinity bottom before'
# Index 11: 'Pump time'
# Index 12: 'Recharge time'
# Index 13: 'Temp top after'
# Index 14: 'Temp bottom after'
# Index 15: 'SPC top after'
# Index 16: 'SPC bottom after'
# Index 17: 'Cond top after'
# Index 18: 'Cond bottom after'
# Index 19: 'Salinity top after'
# Index 20: 'Salinity bottom after'
# Index 21: 'Notes'

# %%
print(mandf.columns)
# Out:
# Index(['Well', 'Date', 'Depth to water', 'Temp top before',
#        'Temp bottom before', 'SPC top before', 'SPC bottom before',
#        'Cond top before ', 'Cond bottom before ', 'Salinity top before',
#        'Salinity bottom before', 'Pump time', 'Recharge time',
#        'Temp top after', 'Temp bottom after', 'SPC top after',
#        'SPC bottom after', 'Cond top after', 'Cond bottom after',
#        'Salinity top after', 'Salinity bottom after', 'Notes'],
#       dtype='str')

# %%
mandf = pd.read_csv("Well_Sampling_Data_P1.csv", 
                    #index_col = 3,
                   )

#mandf.loc[:,"Temp top before"]
mandf.loc[:,"Temp bottom before"]
# Out:
# 0      NaN
# 1      NaN
# 2     18.0
# 3     17.2
# 4     15.7
# 5     15.6
# 6     15.0
# 7     14.2
# 8      9.2
# 9      8.9
# 10     7.5
# 11     6.7
# 12     6.3
# 13     6.0
# 14     5.6
# 15     5.4
# 16     5.5
# 17     5.6
# 18     5.8
# 19     7.3
# 20     7.0
# 21     7.2
# 22     7.8
# 23     9.8
# Name: Temp bottom before, dtype: float64

# %%
hobodf = pd.read_csv("P1_All_6.16.csv")
hobodf["Date-Time (CST/CDT)"] = pd.to_datetime(hobodf["Date-Time (CST/CDT)"])
mandf = pd.read_csv("Well_Sampling_Data_P1.csv")
mandf["Date"] = pd.to_datetime(mandf["Date"])

print(mandf.columns.tolist())
mandf.columns = mandf.columns.str.strip()

# date = hobodf["Date-Time (CST/CDT)"]
# temp = hobodf["Temperature (W-CT 22414702), °C"]
# mandate = mandf["Date"]
# mantemp1 = mandf["Temp top before"]

fig, ax = plt.subplots(layout='constrained')
ax.plot(date, temp, color="blue", label = "HOBO continuous temperature")
ax.plot(mandf.Date, mandf.loc[:,"Temp top before"], 'x', color = "orange", label = "manual temperature at top before pumping")
ax.plot(mandf.Date, mandf.loc[:,"Temp bottom before"], 'x', color = "purple", label = "manual temperature at bottom before pumping")
ax.plot(mandf.Date, mandf.loc[:,"Temp top after"], 'o', color = "orange", label = "manual temperature at top after pumping")
ax.plot(mandf.Date, mandf.loc[:,"Temp bottom after"], 'o', color = "purple", label = "manual temperature at bottom after pumping")
plt.xticks(rotation=45)
plt.xlabel("Year-Month")
plt.ylabel("Temperature (°C)")


#code below places legend outside graph, but squishes it
#plt.legend(bbox_to_anchor=(1.05, 0.5), loc="center left")

#code below places legend on graph and covers some of the data
#ax.legend(loc="lower left")

#code below puts legend outside of graph, squishes it down, but is not awful
fig.legend(loc='outside upper right')
#ax.legend(handles = [hobo, temptb, tempbb, tempta, tempba], labels = ["HOBO continuous data", "field data at top before pumping", "field data at bottom before pumping", "field data at top after pumping", "field data at bottom after pumping"])

plt.show()
# Out:
# ['Well', 'Date', 'Depth to water', 'Temp top before', 'Temp bottom before', 'SPC top before', 'SPC bottom before', 'Cond top before ', 'Cond bottom before ', 'Salinity top before', 'Salinity bottom before', 'Pump time', 'Recharge time', 'Temp top after', 'Temp bottom after', 'SPC top after', 'SPC bottom after', 'Cond top after', 'Cond bottom after', 'Salinity top after', 'Salinity bottom after', 'Notes']

# %%
df = pd.read_csv("P1_Month_MayOnly.csv")
df["Date-Time (CST/CDT)"] = pd.to_datetime(df["Date-Time (CST/CDT)"])

may_time = df["Date-Time (CST/CDT)"]
may_temp = df["Temperature (W-CT 22414702), °C"]

plt.figure(figsize=(10, 5))
plt.plot(may_time, may_temp, color="blue")
plt.xlabel("Month-Day")
plt.ylabel("Temperature (°C)")
plt.title("Continuous P1 temperature in May")

plt.show()

# %%
df = pd.read_csv("P1_Day_June15Only.csv")
df["Date-Time (CST/CDT)"] = pd.to_datetime(df["Date-Time (CST/CDT)"])

may_time = df["Date-Time (CST/CDT)"]
may_temp = df["Temperature (W-CT 22414702), °C"]

plt.figure(figsize=(10, 5))
plt.plot(may_time, may_temp, color="blue")
plt.xlabel("Day-Time")
plt.ylabel("Temperature (°C)")
plt.title("Continuous P1 temperature on 6.15.26")

plt.show()
