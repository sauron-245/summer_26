# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
import os

print(os.getcwd())
print(os.listdir("."))
# Out:
# C:\Users\HydroResearch\Desktop\summer 2026
# ['.ipynb_checkpoints', 'bell2026.ipynb', 'P1 Well (22430782) 2026-06-16 09_33_25 CDT.xlsx - Data.csv']

# %%
df = pd.read_csv("P1_All_6.16.csv")
df["Date-Time (CST/CDT)"] = pd.to_datetime(df["Date-Time (CST/CDT)"])

date = df["Date-Time (CST/CDT)"]
temp = df["Temperature (W-CT 22414702), °C"]

df = pd.read_csv("P1_ManualData.csv")

mandate = 

plt.figure(figsize=(10, 5))
plt.plot(date, temp, color="blue")
plt.xlabel("Year-Month")
plt.ylabel("Temperature (°C)")
plt.title("Continuous P1 temperature")

plt.show()

# %%
df = pd.read_csv("P1_Month_MayOnly.csv")
df["Date-Time (CST/CDT)"] = pd.to_datetime(df["Date-Time (CST/CDT)"])

may_time = df["Date-Time (CST/CDT)"]
may_temp = df["Temperature (W-CT 22414702), °C"]

plt.figure(figsize=(10, 5))
plt.plot(may_time, may_temp, color="blue")
plt.xlabel("Month-Day")
plt.ylabel("Temperature (°C)")
plt.title("Continuous P1 temperature in May")

plt.show()

# %%
df = pd.read_csv("P1_Day_June15Only.csv")
df["Date-Time (CST/CDT)"] = pd.to_datetime(df["Date-Time (CST/CDT)"])

may_time = df["Date-Time (CST/CDT)"]
may_temp = df["Temperature (W-CT 22414702), °C"]

plt.figure(figsize=(10, 5))
plt.plot(may_time, may_temp, color="blue")
plt.xlabel("Day-Time")
plt.ylabel("Temperature (°C)")
plt.title("Continuous P1 temperature on 6.15.26")

plt.show()
